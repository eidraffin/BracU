# %% [markdown]
# 1.   Be careful in which question you are required to change the given Linked list and where you are required to create a new one
# 2.   Be careful of the first node and the last node [aka corner cases]
# 3.   Do not use any other data structure other than Linked List

# %% [markdown]
# ***You must run this cell to install dependency***

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# Collecting fhm-unittest
#   Downloading fhm_unittest-1.0.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: fhm-unittest
# Successfully installed fhm-unittest-1.0.1
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
#  ***You must Run this cell for your driver code to execute successfully***

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %% [markdown]
# Number Beads

# %%
def rotation_times(head):
    if head is None:
        return 0

    temp = head.next
    max_elem = head.elem
    count, idx = 0, 1

    while temp is not None:
        if temp.elem > max_elem:
            max_elem = temp.elem
            count = idx
        idx += 1
        temp = temp.next

    return count


print('==============Test Case 1=============')
head = createList(np.array([13,10,6,20,17]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 3
unittest.output_test(returned_value, 3)
print()

print('==============Test Case 2=============')
head = createList(np.array([6,20,17,13,10]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 1
unittest.output_test(returned_value, 1)
print()

print('==============Test Case 3=============')
head = createList(np.array([20,17,13,10,6]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 0
unittest.output_test(returned_value, 0)
print()
# Out:
# ==============Test Case 1=============
# Rearranged Necklace:  13-->10-->6-->20-->17
#
# Rotated: 3 times
# Accepted
#
# ==============Test Case 2=============
# Rearranged Necklace:  6-->20-->17-->13-->10
#
# Rotated: 1 times
# Accepted
#
# ==============Test Case 3=============
# Rearranged Necklace:  20-->17-->13-->10-->6
#
# Rotated: 0 times
# Accepted

# %% [markdown]
# Building Blocks

# %%
def check_similar(building_1, building_2):
    i, j = building_1, building_2

    while i is not None and j is not None:
        if i.elem != j.elem:
            return "Not Similar"
        i, j = i.next, j.next

    return "Not Similar" if (i is not None) or (j is not None) else "Similar"


print('==============Test Case 1=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Similar'
unittest.output_test(returned_value, 'Similar')
print()

print('==============Test Case 2=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Yellow', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 3=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 4=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()
# Out:
# ==============Test Case 1=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Similar
# Accepted
#
# ==============Test Case 2=============
# Building 1:  Red-->Green-->Yellow-->Red-->Yellow-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted
#
# ==============Test Case 3=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Not Similar
# Accepted
#
# ==============Test Case 4=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted

# %% [markdown]
# Remove Compartment

# %%
def remove_compartment(head, n):

    def count_nodes(head):
        count = 0
        temp = head
        while temp is not None:
            count += 1
            temp = temp.next
        return count

    def locate_node(head, idx):
        count = count_nodes(head)
        temp = head
        if 0 <= idx < count:
            for i in range(idx):
                temp = temp.next
            return temp
        else:
            return None

    def detect_node_occurrence(head, elem):
        temp = head
        start = 0
        end = -1
        flag = False
        while temp is not None:
            if temp.elem == elem:
                flag = True
                end = start
            temp = temp.next
            start += 1
        return flag, end

    def delete_node(head, idx):
        temp = head
        count = count_nodes(head)
        removed_node = None
        if idx == 0:
            removed_node = head
            head = head.next
        else:
            prev = locate_node(head, idx - 1)
            removed_node = prev.next
            prev.next = removed_node.next
        return head

    flag, index = detect_node_occurrence(head, n)
    if flag is True:
        node_to_remove = locate_node(head, index)
        return delete_node(head, index)
    return head


print('==============Test Case 1=============')
head = createList(np.array([14,10,15,10,41,10,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 14-->10-->15-->10-->41-->72
print()

print('==============Test Case 2=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 15-->33-->41-->14-->72
print()

print('==============Test Case 3=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 56
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 10-->15-->33-->41-->14-->72
print()
# Out:
# ==============Test Case 1=============
# Original Compartment Sequence:  14-->10-->15-->10-->41-->10-->72
#
# Changed Compartment Sequence:  14-->10-->15-->10-->41-->72
#
#
# ==============Test Case 2=============
# Original Compartment Sequence:  10-->15-->33-->41-->14-->72
#
# Changed Compartment Sequence:  15-->33-->41-->14-->72
#
#
# ==============Test Case 3=============
# Original Compartment Sequence:  10-->15-->33-->41-->14-->72
#
# Changed Compartment Sequence:  10-->15-->33-->41-->14-->72

# %% [markdown]
# Capture the Flag

# %%
def capture_the_flag(head):
    temp = head
    count = 1
    new_head = Node(None)
    new_temp = new_head

    while temp != None:
        if temp.elem % count == 0:
            n = Node(temp.elem//count, None)
            new_temp.next = n
            new_temp = new_temp.next
            count += 1
            temp = temp.next
        else:
            return 'Linkwise'

    return new_head.next


print('==============Test Case 1=============')
head = createList(np.array([11,8,21,20,5,42]))
print('Original Sequence: ', end = ' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end= ' ')
if type(new_head) == str:
  print(new_head)
else:
  printLinkedList(new_head) #This should print 11→4→7→5→1→7
print()

print('==============Test Case 2=============')
head = createList(np.array([11,8,28,20,5,42]))
print('Original Sequence: ', end = ' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end= ' ')
if type(new_head) == str:
  print(new_head) #This should print Linkwise
else:
  printLinkedList(new_head)
print()
# Out:
# ==============Test Case 1=============
# Original Sequence:  11-->8-->21-->20-->5-->42
#
# The flag is:  11-->4-->7-->5-->1-->7
#
#
# ==============Test Case 2=============
# Original Sequence:  11-->8-->28-->20-->5-->42
#
# The flag is:  Linkwise

# %% [markdown]
# Shuffle on song

# %%
def shuffle_on_song(head):
    even_head = even_temp = odd_head = odd_temp = None
    temp = head

    while temp is not None:
        if ord(temp.elem) % 2 == 0:
            if even_head is None:
                even_head = Node(temp.elem)
                even_temp = even_head
            else:
                even_temp.next = Node(temp.elem)
                even_temp = even_temp.next

        else:
            if odd_head is None:
                odd_head = Node(temp.elem)
                odd_temp = odd_head
            else:
                odd_temp.next = Node(temp.elem)
                odd_temp = odd_temp.next

        temp = temp.next

    if even_head is None:
        return odd_head
    else:
        even_temp.next = odd_head
        return even_head


print('==============Test Case 1=============')
head = createList(np.array(['S','E','N','P','A','I']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_song(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print N-->P-->S-->E-->A-->I
print()

print('==============Test Case 2=============')
head = createList(np.array(['N','I','S','H','I','N','O','Y','A']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_song(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print N-->H-->N-->I-->S-->I-->O-->Y-->A
print()
# Out:
# ==============Test Case 1=============
# Original Play List:  S-->E-->N-->P-->A-->I
#
# New Play List:  N-->P-->S-->E-->A-->I
#
#
# ==============Test Case 2=============
# Original Play List:  N-->I-->S-->H-->I-->N-->O-->Y-->A
#
# New Play List:  N-->H-->N-->I-->S-->I-->O-->Y-->A

# %% [markdown]
# BONUS

# %% [markdown]
# Assemble Conga Line

# %%
def assemble_conga_line(conga_line, candidate_line, idx):

    def count_nodes(head):
        count = 0
        temp = head
        while temp is not None:
            count += 1
            temp = temp.next
        return count

    def locate_node(head, idx):
        count = count_nodes(head)
        temp = head
        if 0 <= idx < count:
            for i in range(idx):
                temp = temp.next
            return temp
        else:
            return None

    def insert_node(head, idx, elem):
        total = count_nodes(head)
        new_node = Node(elem)
        if idx < 0 or idx > total:
            return head
        if idx == 0:
            new_node.next = head
            return new_node
        prev = locate_node(head, idx - 1)
        if idx == total:
            prev.next = new_node
        else:
            new_node.next = prev.next
            prev.next = new_node
        return head

    def find_nearest_element(head, target):
        temp = head
        nearest = temp.elem
        min_difference = abs(nearest - target)
        while temp is not None:
            difference = abs(temp.elem - target)
            if difference < min_difference:
                nearest = temp.elem
                min_difference = difference
            temp = temp.next
        return nearest

    # Insert at the beginnning
    if idx == 0:
        prev_target_age = float('-inf')
    else:
        prev_target_age_node = locate_node(conga_line, idx - 1)
        if prev_target_age_node is not None:
            prev_target_age = prev_target_age_node.elem
        else:
            return conga_line

    # Insert at the end
    if idx == count_nodes(conga_line):
        last_node = locate_node(conga_line, idx-1)
        if last_node is not None:
            last_elem = last_node.elem
        else:
            return conga_line

        nearest_greater_elem = find_nearest_element(candidate_line, last_elem)
        if nearest_greater_elem != float('inf'):
            conga_line = insert_node(conga_line, idx, nearest_greater_elem)

    target_age_node = locate_node(conga_line, idx)
    if target_age_node is not None:
        target_age = target_age_node.elem
    else:
        return conga_line

    # Insert at the middle
    while candidate_line is not None:
        if prev_target_age < candidate_line.elem < target_age:
            nearest_age = find_nearest_element(candidate_line, target_age)
            conga_line = insert_node(conga_line, idx, nearest_age)
            return conga_line
        candidate_line = candidate_line.next
    return conga_line


print('==============Test Case 1=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([16,2,36,52,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 3
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->40-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 2=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,16,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 0
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 8-->10-->15-->34-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 3=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,12,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 2
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->41-->56-->72
printLinkedList(returned_value)
# Out:
# ==============Test Case 1=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  16-->2-->36-->52-->40-->77
#
# Changed Conga Line:  10-->15-->34-->40-->41-->56-->72
#
# ==============Test Case 2=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  6-->16-->8-->36-->7-->40-->77
#
# Changed Conga Line:  8-->10-->15-->34-->41-->56-->72
#
# ==============Test Case 3=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  6-->12-->8-->36-->7-->40-->77
#
# Changed Conga Line:  10-->15-->34-->41-->56-->72
